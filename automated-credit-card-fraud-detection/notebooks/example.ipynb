# %% [markdown]
# # Example EDA and Training
#
# This notebook demonstrates loading the sample data and running the training script.

# %%
import pandas as pd
df = pd.read_csv('data/sample.csv')
df.head()
